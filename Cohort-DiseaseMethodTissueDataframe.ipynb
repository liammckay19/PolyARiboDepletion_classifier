# %%
import os, fnmatch
import matplotlib.pyplot as plt
import csv
import numpy as np
import pandas as pd
import sys
import json
import glob

# %%
clinical = pd.read_csv("/data/archive/compendium/v5/clinical.tsv",sep='\t')

ribodDiagnosis = pd.read_csv("riboDepleted_samples_that_passedQC_and_have_known_diagnosis.tsv", sep='\t')

ribodDiagnosis=ribodDiagnosis.rename(columns={'Treehouse SAMPLE identifier':'th_sampleid','Diagnosis/Disease':'disease'})

methods = pd.read_csv("TranscriptMethod_THPEDv1.csv")

methods = methods.rename(columns={'Treehouse SAMPLE identifier':'th_sampleid'})

clinicalIdTissue = clinical[['th_sampleid','anat_sample','disease']] 
df = pd.merge(clinicalIdTissue, ribodDiagnosis, how='outer', on='th_sampleid')
df = pd.merge(df,methods,how='left',on='th_sampleid')
df.disease_y.fillna(df.disease_x, inplace=True)
df=df.rename(columns={'disease_y':'disease','anat_sample':'tissue'})

del df['disease_x']

df.tissue.fillna('NA',inplace=True)
allSamplesDroppedNA = df.dropna()

# %%
allSamplesDroppedNA
# Out:
#           th_sampleid                                             tissue  \
# 0       TH03_0010_S01                                                 NA
# 1       TH03_0010_S02                                                 NA
# 2       TH03_0103_S01                                                 NA
# 3       TH03_0104_S01                                                 NA
# 4       TH03_0105_S01                                                 NA
# 5       TH03_0106_S01                                                 NA
# 6       TH03_0107_S01                                                 NA
# 7       TH03_0011_S01                                                 NA
# 8       TH03_0112_S01                                    left chest mass
# 9       TH03_0112_S02                                    left chest mass
# 10      TH03_0113_S01                                       liver biopsy
# 11      TH03_0113_S02                                    liver resection
# 12      TH03_0114_S01                                                 NA
# 13      TH03_0115_S01                                  peritoneal lesion
# 14      TH03_0116_S01                                                 NA
# 15      TH03_0117_S01                                                 NA
# 16      TH03_0118_S01                                                 NA
# 17      TH03_0012_S01                                        pelvic mass
# 18      TH03_0012_S02  pelvic mass - residual tumor from previous spe...
# 19      TH03_0013_S01                                        bone marrow
# 20      TH03_0013_S02                                        bone marrow
# 21      TH03_0139_S01                              mandibular recurrence
# 22      TH03_0014_S01                                       nasal septum
# 23      TH03_0140_S01                           diagnostic biopsy (bone)
# 24      TH03_0141_S01                                      femur relapse
# 25      TH03_0143_S01                                     bone - humerus
# 26      TH03_0143_S02                                    lung metastasis
# 27      TH03_0144_S01                                                 NA
# 28      TH03_0146_S01                                         paraspinal
# 29      TH03_0148_S01                                lung nodule relapse
# ...               ...                                                ...
# 11397  THR21_0532_S01                                                 NA
# 11398  THR21_0532_S02                                                 NA
# 11399  THR21_0532_S03                                                 NA
# 11400  THR21_0533_S01                                                 NA
# 11401  THR21_0534_S01                                                 NA
# 11402  THR21_0537_S01                                                 NA
# 11403  THR21_0538_S01                                                 NA
# 11404  THR21_0539_S01                                                 NA
# 11405  THR21_0540_S01                                                 NA
# 11406  THR21_0541_S01                                                 NA
# 11407  THR21_0542_S01                                                 NA
# 11408  THR21_0543_S01                                                 NA
# 11409  THR21_0544_S01                                                 NA
# 11410  THR21_0545_S01                                                 NA
# 11411  THR21_0546_S01                                                 NA
# 11412  THR21_0547_S01                                                 NA
# 11413  THR21_0548_S01                                                 NA
# 11414  THR21_0549_S01                                                 NA
# 11415  THR21_0550_S01                                                 NA
# 11416  THR21_0551_S01                                                 NA
# 11417  THR21_0552_S01                                                 NA
# 11418  THR21_0553_S01                                                 NA
# 11419  THR21_0554_S01                                                 NA
# 11420  THR21_0554_S02                                                 NA
# 11421  THR21_0555_S01                                                 NA
# 11422  THR21_0556_S01                                                 NA
# 11423  THR21_0557_S01                                                 NA
# 11424  THR21_0558_S01                                                 NA
# 11425  THR21_0559_S01                                                 NA
# 11426  THR21_0560_S01                                                 NA
#
#                                       disease  TR_method
# 0         acute leukemia of ambiguous lineage      PolyA
# 1         acute leukemia of ambiguous lineage      PolyA
# 2                            rhabdomyosarcoma      PolyA
# 3                              hepatoblastoma      PolyA
# 4                            rhabdomyosarcoma      PolyA
# 5                                     sarcoma      PolyA
# 6                              hepatoblastoma      PolyA
# 7                acute lymphoblastic leukemia      PolyA
# 8                                     sarcoma      PolyA
# 9                                     sarcoma      PolyA
# 10       myoepithelial carcinoma of the liver      PolyA
# 11       myoepithelial carcinoma of the liver      PolyA
# 12     fibrolamellar hepatocellular carcinoma      PolyA
# 13                                   teratoma      PolyA
# 14                             hepatoblastoma      PolyA
# 15                                     glioma      PolyA
# 16                     acute myeloid leukemia      PolyA
# 17                                wilms tumor      PolyA
# 18                                wilms tumor      PolyA
# 19               acute lymphoblastic leukemia      PolyA
# 20               acute lymphoblastic leukemia      PolyA
# 21                               osteosarcoma      PolyA
# 22                                    sarcoma      PolyA
# 23                               osteosarcoma      PolyA
# 24                               osteosarcoma      PolyA
# 25                               osteosarcoma      PolyA
# 26                               osteosarcoma      PolyA
# 27                                wilms tumor      PolyA
# 28                                    sarcoma      PolyA
# 29                                   lymphoma      PolyA
# ...                                       ...        ...
# 11397                 glioblastoma multiforme  RiboMinus
# 11398                 glioblastoma multiforme  RiboMinus
# 11399                 glioblastoma multiforme  RiboMinus
# 11400                 glioblastoma multiforme  RiboMinus
# 11401                 glioblastoma multiforme  RiboMinus
# 11402                 glioblastoma multiforme  RiboMinus
# 11403                 glioblastoma multiforme  RiboMinus
# 11404                 glioblastoma multiforme  RiboMinus
# 11405                 glioblastoma multiforme  RiboMinus
# 11406                 glioblastoma multiforme  RiboMinus
# 11407                 glioblastoma multiforme  RiboMinus
# 11408                 glioblastoma multiforme  RiboMinus
# 11409                 glioblastoma multiforme  RiboMinus
# 11410                 glioblastoma multiforme  RiboMinus
# 11411                 glioblastoma multiforme  RiboMinus
# 11412                 glioblastoma multiforme  RiboMinus
# 11413                 glioblastoma multiforme  RiboMinus
# 11414                 glioblastoma multiforme  RiboMinus
# 11415                 glioblastoma multiforme  RiboMinus
# 11416                 glioblastoma multiforme  RiboMinus
# 11417                 glioblastoma multiforme  RiboMinus
# 11418                 glioblastoma multiforme  RiboMinus
# 11419                 glioblastoma multiforme  RiboMinus
# 11420                 glioblastoma multiforme  RiboMinus
# 11421                 glioblastoma multiforme  RiboMinus
# 11422                 glioblastoma multiforme  RiboMinus
# 11423                 glioblastoma multiforme  RiboMinus
# 11424                 glioblastoma multiforme  RiboMinus
# 11425                 glioblastoma multiforme  RiboMinus
# 11426                 glioblastoma multiforme  RiboMinus
#
# [11045 rows x 4 columns]
